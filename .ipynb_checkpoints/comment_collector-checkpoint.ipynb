# %%
# get html and return subject polarity
# Find related videos from other channels to compare topic polarization
import os
import pandas as pd
from scipy import spatial
from nltk.chunk import conlltags2tree
from spacy import displacy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import config

key = os.path.join(config.dirs['apis'],'youtube_secret_key.json')
SCOPES = 'https://www.googleapis.com/auth/youtube.force-ssl'
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'

def get_authenticated_service():
    flow = InstalledAppFlow.from_client_secrets_file(key, SCOPES)
    credentials = flow.run_console()
    return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

def get_videos(service, **kwargs):
    final_results = []
    results = service.search().list(**kwargs).execute()
 
    i = 0
    max_pages = 3
    while results and i < max_pages:
        final_results.extend(results['items'])
        # Check if another page exists
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.search().list(**kwargs).execute()
            i += 1
        else:
            break
 
    return final_results

def search_videos_by_keyword(service, **kwargs):
    results = get_videos(service, **kwargs)
    final_results = []
    for item in results:
        title = item['snippet']['title']
        video_id = item['id']['videoId']
        comments = get_video_comments(service, part='snippet', videoId=video_id, textFormat='plainText')
        final_results.extend([(video_id, title, comment) for comment in comments])
    return final_results

def find_channel_id(service, search_term):
    request = service.channels().list(
    forUsername=search_term,
    part='id,snippet'
    ).execute()
    channel_id = request['items'][0]['id']
    return channel_id

def search_channels(service, search_term):
    request = service.search().list(
        q=search_term,
        part='id,snippet',
        type='channel',
        maxResults='20'
    ).execute()
    
    channel_df = pd.DataFrame(columns=['channel_id','channel'])
    for results in request:
        chan = request['items'][0]['channelTitle']
        c_id = request['items'][0]['channelId']
        channel_df = channel_df.append(pd.Series([chan, c_id],index=channel_df.columns), ignore_index = True)
    
    return channel_df

def get_video_comments(service, **kwargs):
    # results = service.commentThreads().list(
    #     part='snippet',
    #     videoId='h2RzmSAZ4Hc',
    #     textFormat='plainText'
    #     ).execute()
    # results
    comment_df = pd.DataFrame(columns=['author','comment','likes'])
    results = service.commentThreads().list(**kwargs).execute()
 
    while results:
        for item in results['items']:
            author = item['snippet']['topLevelComment']['snippet']['authorChannelId']
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            likes = item['snippet']['topLevelComment']['snippet']['likeCount']
            comment_df = comment_df.append(pd.Series([author,comment,likes],index=comment_df.columns), ignore_index = True)
 
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.commentThreads().list(**kwargs).execute()
        else:
            break
 
    return comment_df

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
service = get_authenticated_service()

# %%
os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
service = get_authenticated_service()

# %%
keyword = input('Enter a keyword: ')
search_videos_by_keyword(service, q=keyword, part='id,snippet', eventType='completed', type='video')

comments = get_video_comments(service, part='snippet', videoId='h2RzmSAZ4Hc', textFormat='plainText')
# Out:
# Enter a keyword:  What Trump said is unprecedented ... and it's not even Friday
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-20-5812f1496e60> in <module>()
#       1 keyword = input('Enter a keyword: ')
# ----> 2 search_videos_by_keyword(service, q=keyword, part='id,snippet', eventType='completed', type='video')
#
# <ipython-input-19-029d8df86bfa> in search_videos_by_keyword(service, **kwargs)
#      45         title = item['snippet']['title']
#      46         video_id = item['id']['videoId']
# ---> 47         comments = get_video_comments(service, part='snippet', videoId=video_id, textFormat='plainText')
#      48         final_results.extend([(video_id, title, comment) for comment in comments])
#      49     return final_results
#
# <ipython-input-19-029d8df86bfa> in get_video_comments(service, **kwargs)
#      51 def get_video_comments(service, **kwargs):
#      52     comments = []
# ---> 53     results = service.commentThreads().list(**kwargs).execute()
#      54
#      55     while results:
#
# D:\Apps\Anaconda\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131         return positional_wrapper
#     132
#
# D:\Apps\Anaconda\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     854       callback(resp)
#     855     if resp.status >= 300:
# --> 856       raise HttpError(resp, content, uri=self.uri)
#     857     return self.postproc(resp, content)
#     858
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=zc5RMAfg9mA&textFormat=plainText&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.">

# %%
def get_videos(service, **kwargs):
    final_results = []
    results = service.search().list(**kwargs).execute()
    i = 0
    max_pages = 3
    while results and i < max_pages:
        final_results.extend(results['items'])
 
        # Check if another page exists
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.search().list(**kwargs).execute()
            i += 1
        else:
            break
 
    return final_results

def search_videos_by_keyword(service, **kwargs):
    results = get_videos(service, **kwargs)
    return results

    
test = search_videos_by_keyword(service, q='Neural Network Learns to Play Snake', part='id,snippet', eventType='completed', type='video')

# %%
test[1]
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/V6iP4AII4AhqiAsNj6eAAUZ-Vgw"',
#  'id': {'kind': 'youtube#video', 'videoId': 'Sui3BUyIie8'},
#  'kind': 'youtube#searchResult',
#  'snippet': {'channelId': 'UC-FWuMytGJQARZnviW6p8SQ',
#   'channelTitle': 'Geek Code',
#   'description': 'Live! Visit our website if you want to download !',
#   'liveBroadcastContent': 'none',
#   'publishedAt': '2017-06-24T00:36:55.000Z',
#   'thumbnails': {'default': {'height': 90,
#     'url': 'https://i.ytimg.com/vi/Sui3BUyIie8/default.jpg',
#     'width': 120},
#    'high': {'height': 360,
#     'url': 'https://i.ytimg.com/vi/Sui3BUyIie8/hqdefault.jpg',
#     'width': 480},
#    'medium': {'height': 180,
#     'url': 'https://i.ytimg.com/vi/Sui3BUyIie8/mqdefault.jpg',
#     'width': 320}},
#   'title': 'SNAKE NEURAL NETWORK LIVE TRAINING'}}

# %%
request = service.search().list(
    q='cnn',
    part='id,snippet',
    eventType='completed',
    type='video',
    maxResults='3'
    )

# %%
request.execute()
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/8JECkdoEKHsBXhzh2GiDD2b3ha4"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/3JAr-H8sSO2RWhQl5fEyAsN-vsA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'gMCGqsO_bEg'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCef1-8eOpJgud7szVPlZQAQ',
#     'channelTitle': 'CNN-News18',
#     'description': 'Watch all the current, latest and breaking news only on CNN NEWS18 live TV. The one-stop destination for live news on politics, entertainment, sports, gadgets, ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-08-17T13:21:18.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/gMCGqsO_bEg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/gMCGqsO_bEg/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/gMCGqsO_bEg/mqdefault.jpg',
#       'width': 320}},
#     'title': 'CNN-News18 LIVE | English News LIVE 24X7 | LIVE Updates'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/QPTLIJYCOtqQTLiwyzGOQFZfoYA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'DqySNrUAcvo'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCef1-8eOpJgud7szVPlZQAQ',
#     'channelTitle': 'CNN-News18',
#     'description': 'Watch all the current, latest and breaking news only on CNN NEWS18 live TV. The one-stop destination for live news on politics, entertainment, sports, gadgets, ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-08-13T20:48:10.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/DqySNrUAcvo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/DqySNrUAcvo/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/DqySNrUAcvo/mqdefault.jpg',
#       'width': 320}},
#     'title': 'CNN-News18 LIVE | English News LIVE 24X7 | LIVE Updates'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/Oo8s404qEOvQKUHrS11lAT6GSFM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'SZ7bXgpoE50'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCBi2mrWuNuyYy4gbM6fU18Q',
#     'channelTitle': 'ABC News',
#     'description': 'Watch ABC News pre and post coverage of the Democratic debate live from Detroit. Follow the latest live updates from the debate stage here: ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-08-01T05:21:59.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/SZ7bXgpoE50/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/SZ7bXgpoE50/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/SZ7bXgpoE50/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Democratic Debate 2019 Night 2 Pre, Post coverage: Watch live analysis of 2nd presidential debate'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAMQAA',
#  'pageInfo': {'resultsPerPage': 3, 'totalResults': 1000000},
#  'regionCode': 'US'}

# %%
request = service.channels().list(
    forUsername='fox',
    part='id,snippet'
    ).execute()
request
#channel_id = request['items'][0]['id']
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/kS6ybUO2AbMbY6PJYQiTBQ57J3I"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/NWJOgvqPJGfhoKmLhgM2TxVzqMk"',
#    'id': 'UCUTuhx9d0GDlQ2Gj1BmhpfA',
#    'kind': 'youtube#channel',
#    'snippet': {'customUrl': 'Fox',
#     'description': '',
#     'localized': {'description': '', 'title': 'Fox'},
#     'publishedAt': '2005-08-05T22:32:24.000Z',
#     'thumbnails': {'default': {'height': 88,
#       'url': 'https://yt3.ggpht.com/a/AGF-l78et7f0i6LhnpPpBE1sv2_86w68YS6J8QXVoQ=s88-c-k-c0xffffffff-no-rj-mo',
#       'width': 88},
#      'high': {'height': 800,
#       'url': 'https://yt3.ggpht.com/a/AGF-l78et7f0i6LhnpPpBE1sv2_86w68YS6J8QXVoQ=s800-c-k-c0xffffffff-no-rj-mo',
#       'width': 800},
#      'medium': {'height': 240,
#       'url': 'https://yt3.ggpht.com/a/AGF-l78et7f0i6LhnpPpBE1sv2_86w68YS6J8QXVoQ=s240-c-k-c0xffffffff-no-rj-mo',
#       'width': 240}},
#     'title': 'Fox'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
request = service.channels().list(
    id=channel_id,
    part='id,snippet'
    ).execute()
request
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/jtdZ-2M7os2H2NN2kekFXiKw5y8"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/xc82qIk3HuZwLAjind51YguaMQI"',
#    'id': 'UCupvZG-5ko_eiXAupbDfxWw',
#    'kind': 'youtube#channel',
#    'snippet': {'customUrl': 'CNN',
#     'description': "CNN operates as a division of Turner Broadcasting System, which is a subsidiary of Warner Media. CNN identifies itself as -- and is widely known to be - the most trusted source for news and information. The CNN umbrella includes nine cable and satellite television networks, two radio networks, the CNN Digital Network, which is the top network of news Web sites in the United States, and CNN Newsource, the world's most extensively syndicated news service. CNN is proud of our ability to bring you up-to-the-minute news from around the world, as a result of our many extensions.",
#     'localized': {'description': "CNN operates as a division of Turner Broadcasting System, which is a subsidiary of Warner Media. CNN identifies itself as -- and is widely known to be - the most trusted source for news and information. The CNN umbrella includes nine cable and satellite television networks, two radio networks, the CNN Digital Network, which is the top network of news Web sites in the United States, and CNN Newsource, the world's most extensively syndicated news service. CNN is proud of our ability to bring you up-to-the-minute news from around the world, as a result of our many extensions.",
#      'title': 'CNN'},
#     'publishedAt': '2005-10-02T16:06:36.000Z',
#     'thumbnails': {'default': {'height': 88,
#       'url': 'https://yt3.ggpht.com/a/AGF-l79d7bv3lD8Hf5Cu3jBLyekhBnG9tDQt3we-LA=s88-c-k-c0xffffffff-no-rj-mo',
#       'width': 88},
#      'high': {'height': 800,
#       'url': 'https://yt3.ggpht.com/a/AGF-l79d7bv3lD8Hf5Cu3jBLyekhBnG9tDQt3we-LA=s800-c-k-c0xffffffff-no-rj-mo',
#       'width': 800},
#      'medium': {'height': 240,
#       'url': 'https://yt3.ggpht.com/a/AGF-l79d7bv3lD8Hf5Cu3jBLyekhBnG9tDQt3we-LA=s240-c-k-c0xffffffff-no-rj-mo',
#       'width': 240}},
#     'title': 'CNN'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
request = service.search().list(
    q='Mayor de Blasio',
    channelId=channel_id,
    part='id,snippet',
    eventType='completed',
    type='video',
    maxResults='3'
    )

# %%
request.execute()
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/thxDYb21jTlPmuKT-C8lfsSfAds"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/-OKdNHJxw7IarRJfPoFF2lEjbXA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'IYoSGv5WeW4'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCupvZG-5ko_eiXAupbDfxWw',
#     'channelTitle': 'CNN',
#     'description': "Governor Cuomo, Mayor de Blasio and New York Police Commissioner O'Neill join families and other guest at 9/11 ceremony.",
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2018-09-11T16:36:40.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/IYoSGv5WeW4/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/IYoSGv5WeW4/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/IYoSGv5WeW4/mqdefault.jpg',
#       'width': 320}},
#     'title': '9/11 memorial ceremony in New York - September 11th, 2018'}}],
#  'kind': 'youtube#searchListResponse',
#  'pageInfo': {'resultsPerPage': 3, 'totalResults': 1},
#  'regionCode': 'US'}

# %%
def get_video_comments(service, **kwargs):
    # results = service.commentThreads().list(
    #     part='snippet',
    #     videoId='h2RzmSAZ4Hc',
    #     textFormat='plainText'
    #     ).execute()
    # results
    comment_df = pd.DataFrame(columns=['author','comment','likes'])
    results = service.commentThreads().list(**kwargs).execute()
 
    while results:
        for item in results['items']:
            author = item['snippet']['topLevelComment']['snippet']['authorChannelId']
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            likes = item['snippet']['topLevelComment']['snippet']['likeCount']
            comment_df = comment_df.append(pd.Series([author,comment,likes],index=comment_df.columns), ignore_index = True)
 
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.commentThreads().list(**kwargs).execute()
        else:
            break
 
    return comment_df



comments = get_video_comments(service, part='snippet', videoId='h2RzmSAZ4Hc', textFormat='plainText')

# %%
comments
# Out:
#                                     author  \
# 0    {'value': 'UCsKDUhOUUB4QEP31JMwkrkw'}
# 1    {'value': 'UCoetlyPkUiA7nLC_IsLVQ_w'}
# 2    {'value': 'UCpfBxOREvwwX65EqYXRrLTQ'}
# 3    {'value': 'UCoetlyPkUiA7nLC_IsLVQ_w'}
# 4    {'value': 'UCh0wrWmkVP0XFOmldSEX77w'}
# ..                                     ...
# 370  {'value': 'UC4hxNaN_FqjXslqnjvjZxoA'}
# 371  {'value': 'UCQD0yGciGUW_DUJGO6VFtBw'}
# 372  {'value': 'UCKi71kdGB-9Wl5_EEDTQCsg'}
# 373  {'value': 'UCZ880zph14jDpY_d82NmT3g'}
# 374  {'value': 'UCLe9VXOeo18Yw9EsmlIwAyw'}
#
#                                                comment likes
# 0              RAPIST!!! Don Lemon needs to be FIRED!!     0
# 1               Cnn you should be ashamed of yourselfs     1
# 2    I don't know who this dude is but I like him b...     0
# 3       What is this guy saying? Me not understanding.     1
# 4                     I bet Fareed smells really nice!     0
# ..                                                 ...   ...
# 370                                          Early boi     0
# 371  I thought Trump said he would destroy ISIS in ...     9
# 372                one word LEAVE!!! problem solved!!!     6
# 373                            Trump 2020 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸     8
# 374                    Tariffs on China are justified.     7
#
# [375 rows x 3 columns]

# %%
results = service.commentThreads().list(
    part='snippet',
    videoId='h2RzmSAZ4Hc',
    textFormat='plainText'
    ).execute()
results
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/ciUnW7gNmzcW7KNoZfyxmnEkISo"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/VOHRy3MsaBneuWHuv60xZW_jruM"',
#    'id': 'UgweNKD7Wv3vLejTyjN4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/SY3T3_0L96yzoWTYNQIDQqNgipw"',
#      'id': 'UgweNKD7Wv3vLejTyjN4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCjdqUPMT-LWx0ftpEosrDTA'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCjdqUPMT-LWx0ftpEosrDTA',
#       'authorDisplayName': 'T Dub',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/--DWVDBdatSY/AAAAAAAAAAI/AAAAAAAAAAA/jARx7Xkb2kk/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22
AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/364yB6yVAE-jwnYDePW8tLzhWlo"',
#      'id': 'UgwsWzB3oPAfuX8O7_x4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCWP5hu2M_PetYr7BveKRGnA'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCWP5hu2M_PetYr7BveKRGnA',
#       'authorDisplayName': 'John the herbalist G',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-xmvkQSR6Xd4/AAAAAAAAAAI/AAAAAAAAAAA/QVRlsFhwXAQ/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:40:36.000Z',
#       'textDisplay': "No, we need to gtfo. Let them sort out their own problems, even if it takes decades. We can't keep intervening forever. We can't keep changing regimes forever. Same in Africa and South America. Take refugees when necessary, but otherwise, our nation has problems inside we need to take care of",
#       'textOriginal': "No, we need to gtfo. Let them sort out their own problems, even if it takes decades. We can't keep intervening forever. We can't keep changing regimes forever. Same in Africa and South America. Take refugees when necessary, but otherwise, our nation has problems inside we need to take care of",
#       'updatedAt': '2019-08-18T22:40:36.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/KmTaFsL9MtNtMbCLYGbHZrYSqaw"',
#    'id': 'UgzujEogzMya8M6Yttt4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/cCL4LQ8KKM86LBR5U7qYe6HnSag"',
#      'id': 'UgzujEogzMya8M6Yttt4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UChE5ssnHvZEJrJ-fE2AlO1A'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChE5ssnHvZEJrJ-fE2AlO1A',
#       'authorDisplayName': 'Ralph Colerick',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-TIqE4Yrdlc4/AAAAAAAAAAI/AAAAAAAAAAA/qIyuDlEq9WQ/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:40:12.000Z',
#       'textDisplay': 'ALL DEMENTIA DONNIE FAULT',
#       'textOriginal': 'ALL DEMENTIA DONNIE FAULT',
#       'updatedAt': '2019-08-18T22:40:12.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/kZd1dDCmG-TeW8OMXDJ52AjdLtE"',
#    'id': 'UgwEXRKo1qK9Gw-bg894AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/t4pmbnx7Zdxejf1cbWRS8GLO4_Y"',
#      'id': 'UgwEXRKo1qK9Gw-bg894AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UChE5ssnHvZEJrJ-fE2AlO1A'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChE5ssnHvZEJrJ-fE2AlO1A',
#       'authorDisplayName': 'Ralph Colerick',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-TIqE4Yrdlc4/AAAAAAAAAAI/AAAAAAAAAAA/qIyuDlEq9WQ/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:39:52.000Z',
#       'textDisplay': 'ALL DEMENTIA DONNIE FAULT',
#       'textOriginal': 'ALL DEMENTIA DONNIE FAULT',
#       'updatedAt': '2019-08-18T22:39:52.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/J4kkkmP7Xc0HP5vEUNkFO1gHMCg"',
#    'id': 'UgzjUJV6X8ojCk5ayrZ4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/T0aWaJ3HdPoHqujZFhHto4wZ4rg"',
#      'id': 'UgzjUJV6X8ojCk5ayrZ4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UChjMaY58caxZr82rmZqmj1A'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChjMaY58caxZr82rmZqmj1A',
#       'authorDisplayName': 'Edward Williams',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-nHMo3-yi-kg/AAAAAAAAAAI/AAAAAAAAAAA/DKccZx2JZ1g/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:39:42.000Z',
#       'textDisplay': 'Just transfer them to Iran and save all the extra movement.',
#       'textOriginal': 'Just transfer them to Iran and save all the extra movement.',
#       'updatedAt': '2019-08-18T22:39:42.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/HUGMDKaYBAn11HPbfQOZ1SFfgJg"',
#    'id': 'UgxDLzBOGqBIiQQoQFx4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/lzw7s7x6qN0hzsemAWAwXAMlRZM"',
#      'id': 'UgxDLzBOGqBIiQQoQFx4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCwO-A2w8mxbBKLgb0qvhQVw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwO-A2w8mxbBKLgb0qvhQVw',
#       'authorDisplayName': 'Joseph',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-1GPet0ixFsM/AAAAAAAAAAI/AAAAAAAAAAA/ET7aes_IDjg/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:39:05.000Z',
#       'textDisplay': "US Troops Protecting Opium/Heroin in Afghanistan\nhttps://www.youtube.com/watch?v=qW2YWqVpT4E\n\n\nThis started with the death of JFK & the escalation of Vietnam.......after which there was a HUGE heroin rise. Historically, probably before that. But JFK wasn't on board with the escalation in Vietnam, among other things......and that's what happens to a POTUS who isn't following the Military-Industrial Drug plan.",
#       'textOriginal': "US Troops Protecting Opium/Heroin in Afghanistan\nhttps://www.youtube.com/watch?v=qW2YWqVpT4E\n\n\nThis started with the death of JFK & the escalation of Vietnam.......after which there was a HUGE heroin rise. Historically, probably before that. But JFK wasn't on board with the escalation in Vietnam, among other things......and that's what happens to a POTUS who isn't following the Military-Industrial Drug plan.",
#       'updatedAt': '2019-08-18T22:39:05.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/Adha0Sbkg8BQcnwFnuhwL4gHALU"',
#    'id': 'UgxhgjW_dFY0kzbR3FF4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/sJhj_DdMpJCaDqndScdQ4hovdp8"',
#      'id': 'UgxhgjW_dFY0kzbR3FF4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCplz1FIAfPqE0qG1Kz4Y7fg'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCplz1FIAfPqE0qG1Kz4Y7fg',
#       'authorDisplayName': 'Margaret Nicol',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-e5SkHdv9ypk/AAAAAAAAAAI/AAAAAAAAAAA/MOnZ4KaLnzo/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:38:34.000Z',
#       'textDisplay': 'What did Trump say about there being no more ISIS???  Tell that to this wedding party.\nIn a TV interview, Mirwais Elmi said his bride survived but his brother and other relatives were among the 63 people killed in Saturday\'s attack.\xa0 The Islamic State group has admitted carrying out the bombing, which also wounded more than 180.\xa0 President Ashraf Ghani described the attack as "barbaric".\xa0 He blamed the Taliban for "providing a platform to terrorists". The Taliban, who are engaged in peace talks with the US, condemned the attack.',
#       'textOriginal': 'What did Trump say about there being no more ISIS???  Tell that to this wedding party.\nIn a TV interview, Mirwais Elmi said his bride survived but his brother and other relatives were among the 63 people killed in Saturday\'s attack.\xa0 The Islamic State group has admitted carrying out the bombing, which also wounded more than 180.\xa0 President Ashraf Ghani described the attack as "barbaric".\xa0 He blamed the Taliban for "providing a platform to terrorists". The Taliban, who are engaged in peace talks with the US, condemned the attack.',
#       'updatedAt': '2019-08-18T22:38:34.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/MKuz9YhlYgiTZFTF1iE67RdLhF0"',
#    'id': 'UgyRvLwpuXOTVVTYTLN4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/FxB6oHrySkW5tV9EItvLXUul7nQ"',
#      'id': 'UgyRvLwpuXOTVVTYTLN4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCmaQNde64apn_RrIFB2Zoig'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCmaQNde64apn_RrIFB2Zoig',
#       'authorDisplayName': 'G Lee',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-zSNvug0_wno/AAAAAAAAAAI/AAAAAAAAAAA/TzUgTPNqSxo/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:38:27.000Z',
#       'textDisplay': 'Maybe we should focus more on Domestic Terrorism you only the actual problem in America.',
#       'textOriginal': 'Maybe we should focus more on Domestic Terrorism you only the actual problem in America.',
#       'updatedAt': '2019-08-18T22:38:27.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/lRkdawFuSgogIInQIbVpFN-36uA"',
#    'id': 'Ugz6UXLatb--y7DSjq94AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/kHSrg43RPLmSSm1c4aJ2cMJtkJQ"',
#      'id': 'Ugz6UXLatb--y7DSjq94AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCIQ9u6oOHbD0lg0PPXtd6Lg'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCIQ9u6oOHbD0lg0PPXtd6Lg',
#       'authorDisplayName': 'CITRUS KNIGHT',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-DVOuJah_Pbc/AAAAAAAAAAI/AAAAAAAAAAA/Nt7glf-RjcA/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 3,
#       'publishedAt': '2019-08-18T22:36:40.000Z',
#       'textDisplay': 'FAREED IS A GLOBALIST PROPAGANDIST.',
#       'textOriginal': 'FAREED IS A GLOBALIST PROPAGANDIST.',
#       'updatedAt': '2019-08-18T22:36:40.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/3lodjxnA5G3QgLis5mroEtrb4j0"',
#    'id': 'UgzfgRnh7-id7ddCxqd4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/GaiRHo3sSeMvgYF_oLCLlQWjdog"',
#      'id': 'UgzfgRnh7-id7ddCxqd4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UC5mAtSLlKIWX7cO9X18brgA'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC5mAtSLlKIWX7cO9X18brgA',
#       'authorDisplayName': 'American guy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-YT_X_53330g/AAAAAAAAAAI/AAAAAAAAAAA/0GMokDSUVIQ/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-18T22:36:10.000Z',
#       'textDisplay': 'Can’t Afghanistan make their own military and use it to deal with the terrorists rather than call for america for help?',
#       'textOriginal': 'Can’t Afghanistan make their own military and use it to deal with the terrorists rather than call for america for help?',
#       'updatedAt': '2019-08-18T22:36:10.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/UuhaydkXjK0yfDePPjStvXPP584"',
#    'id': 'Ugy4z3g_rnrhI74FWwZ4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/uspWOkQPhn2pjJ07aqMQV1kUOl4"',
#      'id': 'Ugy4z3g_rnrhI74FWwZ4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UC3tQRjzlEgUtZ5H_xYVp4jg'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC3tQRjzlEgUtZ5H_xYVp4jg',
#       'authorDisplayName': 'martin killam',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-vvUqJyxxFJU/AAAAAAAAAAI/AAAAAAAAAAA/K15Yq80wij8/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 3,
#       'publishedAt': '2019-08-18T22:35:23.000Z',
#       'textDisplay': 'Trump supports killing ISIS. And he is willing to give them lot of support',
#       'textOriginal': 'Trump supports killing ISIS. And he is willing to give them lot of support',
#       'updatedAt': '2019-08-18T22:35:23.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/uevw2B1QIQD1xB5pG97tR67ZDC0"',
#    'id': 'UgyjnThpW1zIuNatyS94AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/cvEPcbmY_EjuE3gln19whz8j4cI"',
#      'id': 'UgyjnThpW1zIuNatyS94AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCwO-A2w8mxbBKLgb0qvhQVw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwO-A2w8mxbBKLgb0qvhQVw',
#       'authorDisplayName': 'Joseph',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-1GPet0ixFsM/AAAAAAAAAAI/AAAAAAAAAAA/ET7aes_IDjg/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 3,
#       'publishedAt': '2019-08-18T22:29:13.000Z',
#       'textDisplay': "It's hard to bring back your opium from afghanistan🌻🌻🌻 when flying ✈commercial, ain't it Nancy?",
#       'textOriginal': "It's hard to bring back your opium from afghanistan🌻🌻🌻 when flying ✈commercial, ain't it Nancy?",
#       'updatedAt': '2019-08-18T22:29:13.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/qrLDaBIWh6hC74YMyPOf61HusqY"',
#    'id': 'Ugy9moc2baAbUa-iend4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/UxRK2Dgft_0c9k0SWfQOqZF02dg"',
#      'id': 'Ugy9moc2baAbUa-iend4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCGFeqHK-C2oqzYrGUtxzzgQ'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCGFeqHK-C2oqzYrGUtxzzgQ',
#       'authorDisplayName': 'barry Powell',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-UfcJXfmMLbU/AAAAAAAAAAI/AAAAAAAAAAA/AvVUwNCS66Q/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 3,
#       'publishedAt': '2019-08-18T22:28:36.000Z',
#       'textDisplay': 'WHAT IF I TOLD YOU THAT YOUR ENTIRE EDUCATION WAS NOTHING MORE THAN A WELL ORCHESTRATED BRAINWASHING TECHNIQUE.',
#       'textOriginal': 'WHAT IF I TOLD YOU THAT YOUR ENTIRE EDUCATION WAS NOTHING MORE THAN A WELL ORCHESTRATED BRAINWASHING TECHNIQUE.',
#       'updatedAt': '2019-08-18T22:29:36.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/KUoY7vGXrPRQmWSpRE-MrCqu2so"',
#    'id': 'Ugx4bAs1V_qA3WadFcZ4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/uzBeQ1xvrA_4Kyq6S4HHpLbqzoI"',
#      'id': 'Ugx4bAs1V_qA3WadFcZ4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCXMmfmknCUNrwyqI7D_R7aA'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCXMmfmknCUNrwyqI7D_R7aA',
#       'authorDisplayName': 'Hildebeast Clinton',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-q-FmFKSdHqA/AAAAAAAAAAI/AAAAAAAAAAA/SgRv978hfS8/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 4,
#       'publishedAt': '2019-08-18T22:27:04.000Z',
#       'textDisplay': 'As then FBI Director, Robert Mueller falsely testified to Congress that Saddam had WMDs in Iraq.  That gave Dickhead Cheney the green light on six 20+ year wars. 🇺🇸❤️',
#       'textOriginal': 'As then FBI Director, Robert Mueller falsely testified to Congress that Saddam had WMDs in Iraq.  That gave Dickhead Cheney the green light on six 20+ year wars. 🇺🇸❤️',
#       'updatedAt': '2019-08-18T22:27:04.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/RKcDole-PaCaTmdD6X2ay6ja7_0"',
#    'id': 'UgxAbpyNaAOpQfqnVZh4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/6x_ALe9hnq3nXbhJGs6ILZdePBk"',
#      'id': 'UgxAbpyNaAOpQfqnVZh4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCk7FW14hQ5AnvYXu7PbSn3A'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCk7FW14hQ5AnvYXu7PbSn3A',
#       'authorDisplayName': 'Wardiz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-pA_zhI1ptvY/AAAAAAAAAAI/AAAAAAAAAAA/4VmaYLnGeT0/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 2,
#       'publishedAt': '2019-08-18T22:26:13.000Z',
#       'textDisplay': 'Please get FREDO back , we miss him . 😢',
#       'textOriginal': 'Please get FREDO back , we miss him . 😢',
#       'updatedAt': '2019-08-18T22:26:13.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/mTV0e0i05Au96jmYe_1y0uDn-Jk"',
#    'id': 'Ugyp63JZijvZAzM9ns94AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/7RSaeSYjkV9zWIZ2VG8Bi10gtek"',
#      'id': 'Ugyp63JZijvZAzM9ns94AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCKxE9o3kTP6b8sCuLp5d4zg'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKxE9o3kTP6b8sCuLp5d4zg',
#       'authorDisplayName': 'p ace',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-m153HUzd9cY/AAAAAAAAAAI/AAAAAAAAAAA/Cdjalq6QYnM/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 3,
#       'publishedAt': '2019-08-18T22:26:05.000Z',
#       'textDisplay': "Seems cnn doesn't ashame of lying.... It makes me sick.... isis, al-Qaeda and taliban have been supported by our government, Saudis, British, french and z~i~o~s for decades.... Remember when isis attacked iraq with humvis... Those time cnn said, they stole american weapons and cars... Cnn thinks people r infants that can be cheated with an ice cream.... Both side medias lied that much and made up stories that much that nobody can believe them... We don't need a corrupted clown like trump tell us that cnn is fake news because he says it for his own benefits.... Fox news is as fake as cnn... Nbc, abc and cbs too... If our government wouldn't get greedy for free natural resources, none of these terrorist groups could.be invented... Dems and reps created and invented these terrorists to mislead people and to steal tax payers money for pointless wars that people hasn't had any benefits in them",
#       'textOriginal': "Seems cnn doesn't ashame of lying.... It makes me sick.... isis, al-Qaeda and taliban have been supported by our government, Saudis, British, french and z~i~o~s for decades.... Remember when isis attacked iraq with humvis... Those time cnn said, they stole american weapons and cars... Cnn thinks people r infants that can be cheated with an ice cream.... Both side medias lied that much and made up stories that much that nobody can believe them... We don't need a corrupted clown like trump tell us that cnn is fake news because he says it for his own benefits.... Fox news is as fake as cnn... Nbc, abc and cbs too... If our government wouldn't get greedy for free natural resources, none of these terrorist groups could.be invented... Dems and reps created and invented these terrorists to mislead people and to steal tax payers money for pointless wars that people hasn't had any benefits in them",
#       'updatedAt': '2019-08-18T22:26:05.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/gVoTQoBEa0Lsh_jyUnJf6uTniZs"',
#    'id': 'UgyqZUMQ1Kw0-1Vk23F4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/L1Lfhy8ddYZFYMzIBjbyS_h-xSA"',
#      'id': 'UgyqZUMQ1Kw0-1Vk23F4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCoBx7Ebme6ZUal5B95MKgPw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCoBx7Ebme6ZUal5B95MKgPw',
#       'authorDisplayName': 'Masson H',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-VJi06B_Y4FY/AAAAAAAAAAI/AAAAAAAAAAA/6zhS5iOZHII/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 4,
#       'publishedAt': '2019-08-18T22:25:28.000Z',
#       'textDisplay': 'The 2nd amendment was meant to overthrow a tyrannical government. Not to protect yourself against a burglar! So the only option is to give nukes to all Americans! Americans claiming rights based on the 2nd amendment don’t understand the historical context.',
#       'textOriginal': 'The 2nd amendment was meant to overthrow a tyrannical government. Not to protect yourself against a burglar! So the only option is to give nukes to all Americans! Americans claiming rights based on the 2nd amendment don’t understand the historical context.',
#       'updatedAt': '2019-08-18T22:42:01.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/upqpLMgM_RzPnD1s7QFYcaiIED4"',
#    'id': 'Ugzwz9rn_8ltg98TdfN4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/dlreKpLE9JALCohEzA5Q68f5lZ8"',
#      'id': 'Ugzwz9rn_8ltg98TdfN4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCsg3TKjZ2j6dY8b3lb868nQ'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCsg3TKjZ2j6dY8b3lb868nQ',
#       'authorDisplayName': 'Laurell\t  LaurellBay',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-27zxRChO3xI/AAAAAAAAAAI/AAAAAAAAAAA/uloNNGu-Y3M/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 2,
#       'publishedAt': '2019-08-18T22:24:39.000Z',
#       'textDisplay': "Your opinion is meaningless. Why not tell us about Biden touching little girls or China? How about bathroom Booker, knee pads Harris? Fredo..stinky fingers lemon..sex traffickers and pedophiles bill and Hillary? \nHow about some truth..maybe you'll get some ratings you America hating creep",
#       'textOriginal': "Your opinion is meaningless. Why not tell us about Biden touching little girls or China? How about bathroom Booker, knee pads Harris? Fredo..stinky fingers lemon..sex traffickers and pedophiles bill and Hillary? \nHow about some truth..maybe you'll get some ratings you America hating creep",
#       'updatedAt': '2019-08-18T22:24:39.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}}],
#  'kind': 'youtube#commentThreadListResponse',
#  'nextPageToken': 'QURTSl9pMW9kUm1MOHdBYW9neVJtM1RQME9yRDlvM094UUpEbUNRbXhsNVg2eGk5cVdmQlQ3UTBxWDVxMC05ak85OHdmX3JZeFV2VnRsQlNSYlg1SUt5dTVOMEpJbXcwOWQyenlLTlZWUWlhekF5Z3Q1TENldWcwUEhXeTdOM0g=',
#  'pageInfo': {'resultsPerPage': 20, 'totalResults': 20}}

# %%
comment_df = pd.DataFrame(columns=['author','comment','likes'])

c = 'comment'
like = 'likes'
autr = 'authorsss'
comment_df.append(pd.Series([c,like,autr],index=comment_df.columns), ignore_index = True)
# Out:
#     author comment      likes
# 0  comment   likes  authorsss

# %%
def search_channel(service, search_term):
    request = service.search().list(
        q=search_term,
        part='id,snippet',
        type='channel',
        maxResults='20'
    ).execute()
    
    channel_df = pd.DataFrame(columns=['channel_id','channel'])
    for results in request:
        chan = request['items'][0]['channelTitle']
        c_id = request['items'][0]['channelId']
        channel_df = channel_df.append(pd.Series([chan, c_id],index=channel_df.columns), ignore_index = True)
    
    return channel_df
        


def find_channel_id(service, search_term):
    request = service.channels().list(
    forUsername=search_term,
    part='id,snippet'
    ).execute()
    channel_id = request['items'][0]['id']
    return channel_id


comment_df = pd.DataFrame(columns=['author','comment','likes'])
    results = service.commentThreads().list(**kwargs).execute()
 
    while results:
        for item in results['items']:
            author = item['snippet']['topLevelComment']['snippet']['authorChannelId']
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            likes = item['snippet']['topLevelComment']['snippet']['likeCount']
            comment_df = comment_df.append(pd.Series([author,comment,likes],index=comment_df.columns), ignore_index = True)

request = service.search().list(
    q='cnn',
    part='id,snippet',
    type='channel',
    maxResults='20'
    )
request.execute()
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/2S6eo54pG9JE-sVJqQDFyabAO5E"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/f10hjuC3bLJD8gUed_U6_N0H5L0"',
#    'id': {'channelId': 'UCupvZG-5ko_eiXAupbDfxWw', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCupvZG-5ko_eiXAupbDfxWw',
#     'channelTitle': 'CNN',
#     'description': 'CNN operates as a division of Turner Broadcasting System, which is a subsidiary of Warner Media. CNN identifies itself as -- and is widely known to be - the ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2005-10-02T16:06:36.000Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-K12xTWC-rMI/AAAAAAAAAAI/AAAAAAAAAAA/2N_u5pcKB3w/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-K12xTWC-rMI/AAAAAAAAAAI/AAAAAAAAAAA/2N_u5pcKB3w/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/
000Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-ETBmT5dS4tM/AAAAAAAAAAI/AAAAAAAAAAA/Sy0cVhv_U0k/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-ETBmT5dS4tM/AAAAAAAAAAI/AAAAAAAAAAA/Sy0cVhv_U0k/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-ETBmT5dS4tM/AAAAAAAAAAI/AAAAAAAAAAA/Sy0cVhv_U0k/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'title': 'CNN Philippines Life'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/TEaT9f2eY8x5tKRo6tVlsh1k1fc"',
#    'id': {'channelId': 'UC35KuZBNIj4S5Ls0yjY-UHQ', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC35KuZBNIj4S5Ls0yjY-UHQ',
#     'channelTitle': 'GNN',
#     'description': 'A news channel providing credible, authentic and reliable information about the latest news with responsibility. GNN keeps its audience informed round the ...',
#     'liveBroadcastContent': 'live',
#     'publishedAt': '2017-06-13T20:19:53.000Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-jyRbuJPWkyE/AAAAAAAAAAI/AAAAAAAAAAA/pP0yFNO2BtM/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-jyRbuJPWkyE/AAAAAAAAAAI/AAAAAAAAAAA/pP0yFNO2BtM/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-jyRbuJPWkyE/AAAAAAAAAAI/AAAAAAAAAAA/pP0yFNO2BtM/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'title': 'GNN'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CBQQAA',
#  'pageInfo': {'resultsPerPage': 20, 'totalResults': 1000000},
#  'regionCode': 'US'}

# %%
comments.tail()
# Out:
#                                     author  \
# 370  {'value': 'UC4hxNaN_FqjXslqnjvjZxoA'}
# 371  {'value': 'UCQD0yGciGUW_DUJGO6VFtBw'}
# 372  {'value': 'UCKi71kdGB-9Wl5_EEDTQCsg'}
# 373  {'value': 'UCZ880zph14jDpY_d82NmT3g'}
# 374  {'value': 'UCLe9VXOeo18Yw9EsmlIwAyw'}
#
#                                                comment likes
# 370                                          Early boi     0
# 371  I thought Trump said he would destroy ISIS in ...     9
# 372                one word LEAVE!!! problem solved!!!     6
# 373                            Trump 2020 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸     8
# 374                    Tariffs on China are justified.     7

# %%
import spacy

import numpy as np
from datetime import datetime, timedelta

#nlp = spacy.load('en')
nlp = spacy.load('en_core_web_lg')

# %%
from scipy import spatial
from nltk.chunk import conlltags2tree
from spacy import displacy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
nlp = spacy.load('en_core_web_lg')

cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)
 
man = nlp.vocab['man'].vector
woman = nlp.vocab['woman'].vector
queen = nlp.vocab['queen'].vector
king = nlp.vocab['king'].vector
 
# We now need to find the closest vector in the vocabulary to the result of "man" - "woman" + "queen"
maybe_king = man - woman + queen
computed_similarities = []
 
for word in nlp.vocab:
    # Ignore words without vectors
    if not word.has_vector:
        continue
 
    similarity = cosine_similarity(maybe_king, word.vector)
    computed_similarities.append((word, similarity))
 
computed_similarities = sorted(computed_similarities, key=lambda item: -item[1])
print([w[0].text for w in computed_similarities[:10]])

sentiment_analyzer = SentimentIntensityAnalyzer()
def polarity_scores(doc):
    return sentiment_analyzer.polarity_scores(doc.text)
 
Doc.set_extension('polarity_scores', getter=polarity_scores)
 
nlp = spacy.load('en')
doc = nlp("Really Whaaat event apple nice! it!")
print(doc._.polarity_scores)

# %%
from spacy.tokens import Doc
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sentiment_analyzer = SentimentIntensityAnalyzer()
def polarity_scores(doc):
    return sentiment_analyzer.polarity_scores(doc.text)
 
Doc.set_extension('polarity_scores', getter=polarity_scores)
 
nlp = spacy.load('en')
doc = nlp("Really Whaaat event apple nice! it!")
print(doc._.polarity_scores)
# Out:
# {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'compound': 0.5242}

# %%
comment = nlp(comments.loc[18]['comment'])
print(comment)
#print(doc._.polarity_scores)
for sent in comment.sents:
    for token in sent:
        subjects = []
        if token.dep_ == 'nsubj':
            subjects.append(token.text)  
        if token.dep_ == 'amod':
            print(token.text)
    print(sent)
    print(polarity_scores(sent))
    #print()
# [sent.text for sent in doc.sents]
# [ent.text for ent in doc.ents]
#displacy.render(doc, style="dep", jupyter=True)
# Out:
# No, we need to gtfo. Let them sort out their own problems, even if it takes decades. We can't keep intervening forever. We can't keep changing regimes forever. Same in Africa and South America. Take refugees when necessary, but otherwise, our nation has problems inside we need to take care of
# No, we need to gtfo.
# {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'compound': -0.296}
# own
# Let them sort out their own problems, even if it takes decades.
# {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}
# We can't keep intervening forever.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# We can't keep changing regimes forever.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Same in Africa and South America.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Take refugees when necessary, but otherwise, our nation has problems inside we need to take care of
# {'neg': 0.155, 'neu': 0.656, 'pos': 0.188, 'compound': 0.1901}

# %%
comment = nlp(comments.loc[18]['comment'])
for chunk in comment.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)
    
for token in comment:
    print(token.text, token.dep_)
# Out:
# we we nsubj need
# them them nsubj sort
# their own problems problems dobj sort
# it it nsubj takes
# decades decades dobj takes
# We We nsubj keep
# We We nsubj keep
# regimes regimes dobj changing
# Africa Africa pobj in
# South America America conj Africa
# refugees refugees dobj Take
# our nation nation nsubj has
# problems problems dobj has
# we we nsubj need
# care care dobj take
# No intj
# , punct
# we nsubj
# need ROOT
# to prep
# gtfo pobj
# . punct
# Let ROOT
# them nsubj
# sort ccomp
# out prt
# their poss
# own amod
# problems dobj
# , punct
# even advmod
# if mark
# it nsubj
# takes advcl
# decades dobj
# . punct
# We nsubj
# ca aux
# n't neg
# keep ROOT
# intervening xcomp
# forever advmod
# . punct
# We nsubj
# ca aux
# n't neg
# keep ROOT
# changing xcomp
# regimes dobj
# forever advmod
# . punct
# Same ROOT
# in prep
# Africa pobj
# and cc
# South compound
# America conj
# . punct
# Take ROOT
# refugees dobj
# when advmod
# necessary advcl
# , punct
# but cc
# otherwise advmod
# , punct
# our poss
# nation nsubj
# has conj
# problems dobj
# inside advmod
# we nsubj
# need relcl
# to aux
# take xcomp
# care dobj
# of prep

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-3e42b4fe17a9> in <module>()
#       6 #nlp = spacy.load("custom_ner_model")
#       7 doc = nlp(text)
# ----> 8 displacy.serve(doc, style="ent", jupyter=True)
#
# TypeError: serve() got an unexpected keyword argument 'jupyter'
