# %%
# get html and return subject polarity
# Find related videos from other channels to compare topic polarization
import os
import pandas as pd
from scipy import spatial
import spacy
from spacy import displacy
from spacy.tokens import Doc
import nltk
from nltk.chunk import conlltags2tree
from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')

import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import config

nlp = spacy.load('en_core_web_lg')

key = os.path.join(config.dirs['apis'],'youtube_secret_key.json')
SCOPES = 'https://www.googleapis.com/auth/youtube.force-ssl'
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'

def get_authenticated_service():
    flow = InstalledAppFlow.from_client_secrets_file(key, SCOPES)
    credentials = flow.run_console()
    return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

def get_videos(service, **kwargs):
    final_results = []
    results = service.search().list(**kwargs).execute()
 
    i = 0
    max_pages = 3
    while results and i < max_pages:
        final_results.extend(results['items'])
        # Check if another page exists
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.search().list(**kwargs).execute()
            i += 1
        else:
            break
 
    return final_results

def search_videos_by_keyword(service, **kwargs):
    results = get_videos(service, **kwargs)
    final_results = []
    for item in results:
        title = item['snippet']['title']
        video_id = item['id']['videoId']
        comments = get_video_comments(service, part='snippet', videoId=video_id, textFormat='plainText')
        final_results.extend([(video_id, title, comment) for comment in comments])
    return final_results

def find_channel_id(service, search_term):
    request = service.channels().list(
    forUsername=search_term,
    part='id,snippet'
    ).execute()
    channel_id = request['items'][0]['id']
    return channel_id

def search_channels(service, search_term):
    request = service.search().list(
        q=search_term,
        part='id,snippet',
        type='channel',
        maxResults='20'
    ).execute()
    
    channel_df = pd.DataFrame(columns=['channel_id','channel'])
    for results in request:
        chan = request['items'][0]['channelTitle']
        c_id = request['items'][0]['channelId']
        channel_df = channel_df.append(pd.Series([chan, c_id],index=channel_df.columns), ignore_index = True)
    
    return channel_df

def get_video_details(service, video_id):
    # takes a video_id and returns the video title, channel, and description

def get_video_comments(service, **kwargs):
    # results = service.commentThreads().list(
    #     part='snippet',
    #     videoId='h2RzmSAZ4Hc',
    #     textFormat='plainText'
    #     ).execute()
    # results
    comment_df = pd.DataFrame(columns=['author','comment','likes'])
    results = service.commentThreads().list(**kwargs).execute()
 
    while results:
        for item in results['items']:
            author = item['snippet']['topLevelComment']['snippet']['authorChannelId']
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            likes = item['snippet']['topLevelComment']['snippet']['likeCount']
            comment_df = comment_df.append(pd.Series([author,comment,likes],index=comment_df.columns), ignore_index = True)
 
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.commentThreads().list(**kwargs).execute()
        else:
            break
 
    return comment_df

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
service = get_authenticated_service()
# Out:
# D:\Apps\Anaconda\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\JP\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=497586682045-b0ct39o38sflgjhjt09f63cc43uq26dk.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=CMSR8kw6OMfodzbAUk7nxpjY32DjIG&prompt=consent&access_type=offline&code_challenge=Q7Og_zXGaKgO2I8bQM_lIcWd65FSQE2_TDgrhG4VSOw&code_challenge_method=S256
# Enter the authorization code:  4/qQGCKENHtLlWMM1oJDc4-XLsd0bAcpBa8hEU2f7dMWJYSqppU9g2aDM

# %%
#keyword = input('Enter a keyword: ')
#search_videos_by_keyword(service, q=keyword, part='id,snippet', eventType='completed', type='video')

comments = get_video_comments(service, part='snippet', videoId='h2RzmSAZ4Hc', textFormat='plainText')

# %%
comments
# Out:
#                                   author  \
# 0  {'value': 'UC3H3ZmgOxW7bsLwL7PP9z9Q'}
# 1  {'value': 'UCQzxvdElu15Clp4nfwhbHqQ'}
# 2  {'value': 'UCy73WU9s9nX4ZKAdJ0CY-XQ'}
# 3  {'value': 'UC-O7Vn51XF98cdNfXYd1GoQ'}
# 4  {'value': 'UC7bZEBSqVyujNQWB0SCL8dA'}
#
#                                              comment likes
# 0  USA lost the war in Afghanistan. USA don't hav...     0
# 1  Afghans are in danger because India keeps chan...     0
# 2  We should pull out of the Middle East complete...     0
# 3  The primadonald is again talking of “the Harva...     0
# 4                                       send fredo,,     0

# %%
def get_video_details(service, video_id):
    # takes a video_id and returns the video title, channel, and description
    # video_details = get_video_details(service,'h2RzmSAZ4Hc')
    results = service.videos().list(part='snippet',id=video_id).execute()
    return results

video_details = get_video_details(service,'h2RzmSAZ4Hc')

# %%
def extract_video_description(video):
    try:
        description = video['items'][0]['snippet']['description']
        return description
    except:
        print('No description found')
    
def extract_video_title(video):
    try:
        description = video['items'][0]['snippet']['title']
        return description
    except:
        print('No title found')
        
extract_video_description(video_details)
extract_video_title(video_details)
# Out:
# "Fareed's take: How the US should leave Afghanistan"

# %%
from spacy.tokens import Doc
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sentiment_analyzer = SentimentIntensityAnalyzer()
def polarity_scores(doc):
    return sentiment_analyzer.polarity_scores(doc.text)
 
Doc.set_extension('polarity_scores', getter=polarity_scores)
comment = nlp(comments.loc[18]['comment'])
subject_evaluation = pd.DataFrame(columns=['subjects','sent_sentiment'])
for sent in comment.sents:
    #displacy.render(sent, style="dep", jupyter=True)
    sent_sub = []
    subjects = []
    polarity = []
    has_subject = 0
    for chunk in sent.noun_chunks:
        if chunk.root.dep_ == 'nsubj':
            sent_sub.append(chunk.text)
            sent_sub.append([child for child in chunk.root.children])
            has_subject = 1
            
#     for chunk in sent.noun_chunks:
#         print(chunk.text)
#     for token in sent:
        
#         if token.dep_ == 'amod':
#             sent_sub.append(token.text)
#             has_subject = 1
#         if token.dep_ == 'compound':
#             sent_sub.append(token.text)
#             has_subject = 1
#         if token.dep_ == 'nsubj':
#             sent_sub.append(token.text)
#             has_subject = 1
            
    if has_subject == 0:
        sent_sub.append('None')
        
    subjects.append(sent_sub)
    polarity.append(polarity_scores(sent)['compound'])
    subject_evaluation = subject_evaluation.append(pd.Series([subjects, polarity], index=subject_evaluation.columns), ignore_index = True)

#subject_evaluation = subject_evaluation.append([subjects, polarity], ignore_index = True)
#subject_evaluation = subject_evaluation.append(pd.Series([subjects, polarity], index=subject_evaluation.columns), ignore_index = True)

subject_evaluation
            
comment = nlp(comments.loc[18]['comment'])
for chunk in comment.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text,[child for child in chunk.children])
    
for token in comment:
    print(token.text, token.dep_)

# %%
comments.loc[18]['comment']
# Out:
# "How  would you know? you've never been in uniform, have you?"

# %%
nlp = nlp(comments.loc[18]['comment'])
neuralcoref.add_to_pipe(nlp)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-097423cc68ef> in <module>()
#       1 import neuralcoref
#       2 import spacy
# ----> 3 nlp = spacy.load('en_core_web_lg')
#       4 nlp = nlp(comments.loc[18]['comment'])
#       5 neuralcoref.add_to_pipe(nlp)
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\util.py in load_model(name, **overrides)
#     132             return load_model_from_link(name, **overrides)
#     133         if is_package(name):  # installed as package
# --> 134             return load_model_from_package(name, **overrides)
#     135         if Path(name).exists():  # path to model data directory
#     136             return load_model_from_path(Path(name), **overrides)
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\util.py in load_model_from_package(name, **overrides)
#     153     """Load a model from an installed package."""
#     154     cls = importlib.import_module(name)
# --> 155     return cls.load(**overrides)
#     156
#     157
#
# D:\Apps\Anaconda\lib\site-packages\en_core_web_lg\__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\util.py in load_model_from_init_py(init_file, **overrides)
#     194     if not model_path.exists():
#     195         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 196     return load_model_from_path(data_path, meta, **overrides)
#     197
#     198
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\util.py in load_model_from_path(model_path, meta, **overrides)
#     177             component = nlp.create_pipe(name, config=config)
#     178             nlp.add_pipe(component, name=name)
# --> 179     return nlp.from_disk(model_path)
#     180
#     181
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\language.py in from_disk(self, path, exclude, disable)
#     834             # Convert to list here in case exclude is (default) tuple
#     835             exclude = list(exclude) + ["vocab"]
# --> 836         util.from_disk(path, deserializers, exclude)
#     837         self._path = path
#     838         return self
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\util.py in from_disk(path, readers, exclude)
#     634         # Split to support file names like meta.json
#     635         if key.split(".")[0] not in exclude:
# --> 636             reader(path / key)
#     637     return path
#     638
#
# ~\AppData\Roaming\Python\Python36\site-packages\spacy\language.py in <lambda>(p)
#     821         ) and _fix_pretrained_vectors_name(self)
#     822         deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(
# --> 823             p, exclude=["vocab"]
#     824         )
#     825         for name, proc in self.pipeline:
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.from_disk()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.from_bytes()
#
# D:\Apps\Anaconda\lib\re.py in compile(pattern, flags)
#     231 def compile(pattern, flags=0):
#     232     "Compile a regular expression pattern, returning a pattern object."
# --> 233     return _compile(pattern, flags)
#     234
#     235 def purge():
#
# D:\Apps\Anaconda\lib\re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# D:\Apps\Anaconda\lib\sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# D:\Apps\Anaconda\lib\sre_parse.py in parse(str, flags, pattern)
#     853
#     854     try:
# --> 855         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     856     except Verbose:
#     857         # the VERBOSE flag was switched on inside the pattern.  to be
#
# D:\Apps\Anaconda\lib\sre_parse.py in _parse_sub(source, state, verbose, nested)
#     414     while True:
#     415         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 416                            not nested and not items))
#     417         if not sourcematch("|"):
#     418             break
#
# D:\Apps\Anaconda\lib\sre_parse.py in _parse(source, state, verbose, nested, first)
#     525                     break
#     526                 elif this[0] == "\\":
# --> 527                     code1 = _class_escape(source, this)
#     528                 else:
#     529                     code1 = LITERAL, _ord(this)
#
# D:\Apps\Anaconda\lib\sre_parse.py in _class_escape(source, escape)
#     334         if len(escape) == 2:
#     335             if c in ASCIILETTERS:
# --> 336                 raise source.error('bad escape %s' % escape, len(escape))
#     337             return LITERAL, ord(escape[1])
#     338     except ValueError:
#
# error: bad escape \p at position 257

# %%
request = service.search().list(
    q='cnn',
    part='id,snippet',
    eventType='completed',
    type='video',
    maxResults='3'
    )

# %%
request.execute()
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/8JECkdoEKHsBXhzh2GiDD2b3ha4"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/3JAr-H8sSO2RWhQl5fEyAsN-vsA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'gMCGqsO_bEg'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCef1-8eOpJgud7szVPlZQAQ',
#     'channelTitle': 'CNN-News18',
#     'description': 'Watch all the current, latest and breaking news only on CNN NEWS18 live TV. The one-stop destination for live news on politics, entertainment, sports, gadgets, ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-08-17T13:21:18.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/gMCGqsO_bEg/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/gMCGqsO_bEg/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/gMCGqsO_bEg/mqdefault.jpg',
#       'width': 320}},
#     'title': 'CNN-News18 LIVE | English News LIVE 24X7 | LIVE Updates'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/QPTLIJYCOtqQTLiwyzGOQFZfoYA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'DqySNrUAcvo'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCef1-8eOpJgud7szVPlZQAQ',
#     'channelTitle': 'CNN-News18',
#     'description': 'Watch all the current, latest and breaking news only on CNN NEWS18 live TV. The one-stop destination for live news on politics, entertainment, sports, gadgets, ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-08-13T20:48:10.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/DqySNrUAcvo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/DqySNrUAcvo/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/DqySNrUAcvo/mqdefault.jpg',
#       'width': 320}},
#     'title': 'CNN-News18 LIVE | English News LIVE 24X7 | LIVE Updates'}},
#   {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/Oo8s404qEOvQKUHrS11lAT6GSFM"',
#    'id': {'kind': 'youtube#video', 'videoId': 'SZ7bXgpoE50'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCBi2mrWuNuyYy4gbM6fU18Q',
#     'channelTitle': 'ABC News',
#     'description': 'Watch ABC News pre and post coverage of the Democratic debate live from Detroit. Follow the latest live updates from the debate stage here: ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-08-01T05:21:59.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/SZ7bXgpoE50/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/SZ7bXgpoE50/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/SZ7bXgpoE50/mqdefault.jpg',
#       'width': 320}},
#     'title': 'Democratic Debate 2019 Night 2 Pre, Post coverage: Watch live analysis of 2nd presidential debate'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAMQAA',
#  'pageInfo': {'resultsPerPage': 3, 'totalResults': 1000000},
#  'regionCode': 'US'}

# %%
request = service.channels().list(
    forUsername='fox',
    part='id,snippet'
    ).execute()
request
#channel_id = request['items'][0]['id']
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/kS6ybUO2AbMbY6PJYQiTBQ57J3I"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/NWJOgvqPJGfhoKmLhgM2TxVzqMk"',
#    'id': 'UCUTuhx9d0GDlQ2Gj1BmhpfA',
#    'kind': 'youtube#channel',
#    'snippet': {'customUrl': 'Fox',
#     'description': '',
#     'localized': {'description': '', 'title': 'Fox'},
#     'publishedAt': '2005-08-05T22:32:24.000Z',
#     'thumbnails': {'default': {'height': 88,
#       'url': 'https://yt3.ggpht.com/a/AGF-l78et7f0i6LhnpPpBE1sv2_86w68YS6J8QXVoQ=s88-c-k-c0xffffffff-no-rj-mo',
#       'width': 88},
#      'high': {'height': 800,
#       'url': 'https://yt3.ggpht.com/a/AGF-l78et7f0i6LhnpPpBE1sv2_86w68YS6J8QXVoQ=s800-c-k-c0xffffffff-no-rj-mo',
#       'width': 800},
#      'medium': {'height': 240,
#       'url': 'https://yt3.ggpht.com/a/AGF-l78et7f0i6LhnpPpBE1sv2_86w68YS6J8QXVoQ=s240-c-k-c0xffffffff-no-rj-mo',
#       'width': 240}},
#     'title': 'Fox'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
request = service.channels().list(
    id=channel_id,
    part='id,snippet'
    ).execute()
request
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/jtdZ-2M7os2H2NN2kekFXiKw5y8"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/xc82qIk3HuZwLAjind51YguaMQI"',
#    'id': 'UCupvZG-5ko_eiXAupbDfxWw',
#    'kind': 'youtube#channel',
#    'snippet': {'customUrl': 'CNN',
#     'description': "CNN operates as a division of Turner Broadcasting System, which is a subsidiary of Warner Media. CNN identifies itself as -- and is widely known to be - the most trusted source for news and information. The CNN umbrella includes nine cable and satellite television networks, two radio networks, the CNN Digital Network, which is the top network of news Web sites in the United States, and CNN Newsource, the world's most extensively syndicated news service. CNN is proud of our ability to bring you up-to-the-minute news from around the world, as a result of our many extensions.",
#     'localized': {'description': "CNN operates as a division of Turner Broadcasting System, which is a subsidiary of Warner Media. CNN identifies itself as -- and is widely known to be - the most trusted source for news and information. The CNN umbrella includes nine cable and satellite television networks, two radio networks, the CNN Digital Network, which is the top network of news Web sites in the United States, and CNN Newsource, the world's most extensively syndicated news service. CNN is proud of our ability to bring you up-to-the-minute news from around the world, as a result of our many extensions.",
#      'title': 'CNN'},
#     'publishedAt': '2005-10-02T16:06:36.000Z',
#     'thumbnails': {'default': {'height': 88,
#       'url': 'https://yt3.ggpht.com/a/AGF-l79d7bv3lD8Hf5Cu3jBLyekhBnG9tDQt3we-LA=s88-c-k-c0xffffffff-no-rj-mo',
#       'width': 88},
#      'high': {'height': 800,
#       'url': 'https://yt3.ggpht.com/a/AGF-l79d7bv3lD8Hf5Cu3jBLyekhBnG9tDQt3we-LA=s800-c-k-c0xffffffff-no-rj-mo',
#       'width': 800},
#      'medium': {'height': 240,
#       'url': 'https://yt3.ggpht.com/a/AGF-l79d7bv3lD8Hf5Cu3jBLyekhBnG9tDQt3we-LA=s240-c-k-c0xffffffff-no-rj-mo',
#       'width': 240}},
#     'title': 'CNN'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
request = service.search().list(
    q='Mayor de Blasio',
    channelId=channel_id,
    part='id,snippet',
    eventType='completed',
    type='video',
    maxResults='3'
    )

# %%
request.execute()
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/thxDYb21jTlPmuKT-C8lfsSfAds"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/-OKdNHJxw7IarRJfPoFF2lEjbXA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'IYoSGv5WeW4'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCupvZG-5ko_eiXAupbDfxWw',
#     'channelTitle': 'CNN',
#     'description': "Governor Cuomo, Mayor de Blasio and New York Police Commissioner O'Neill join families and other guest at 9/11 ceremony.",
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2018-09-11T16:36:40.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/IYoSGv5WeW4/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/IYoSGv5WeW4/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/IYoSGv5WeW4/mqdefault.jpg',
#       'width': 320}},
#     'title': '9/11 memorial ceremony in New York - September 11th, 2018'}}],
#  'kind': 'youtube#searchListResponse',
#  'pageInfo': {'resultsPerPage': 3, 'totalResults': 1},
#  'regionCode': 'US'}

# %%
def get_video_comments(service, **kwargs):
    # results = service.commentThreads().list(
    #     part='snippet',
    #     videoId='h2RzmSAZ4Hc',
    #     textFormat='plainText'
    #     ).execute()
    # results
    comment_df = pd.DataFrame(columns=['author','comment','likes'])
    results = service.commentThreads().list(**kwargs).execute()
 
    while results:
        for item in results['items']:
            author = item['snippet']['topLevelComment']['snippet']['authorChannelId']
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            likes = item['snippet']['topLevelComment']['snippet']['likeCount']
            comment_df = comment_df.append(pd.Series([author,comment,likes],index=comment_df.columns), ignore_index = True)
 
        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.commentThreads().list(**kwargs).execute()
        else:
            break
 
    return comment_df



comments = get_video_comments(service, part='snippet', videoId='h2RzmSAZ4Hc', textFormat='plainText')

# %%
comments
# Out:
#                                     author  \
# 0    {'value': 'UCsKDUhOUUB4QEP31JMwkrkw'}
# 1    {'value': 'UCoetlyPkUiA7nLC_IsLVQ_w'}
# 2    {'value': 'UCpfBxOREvwwX65EqYXRrLTQ'}
# 3    {'value': 'UCoetlyPkUiA7nLC_IsLVQ_w'}
# 4    {'value': 'UCh0wrWmkVP0XFOmldSEX77w'}
# ..                                     ...
# 370  {'value': 'UC4hxNaN_FqjXslqnjvjZxoA'}
# 371  {'value': 'UCQD0yGciGUW_DUJGO6VFtBw'}
# 372  {'value': 'UCKi71kdGB-9Wl5_EEDTQCsg'}
# 373  {'value': 'UCZ880zph14jDpY_d82NmT3g'}
# 374  {'value': 'UCLe9VXOeo18Yw9EsmlIwAyw'}
#
#                                                comment likes
# 0              RAPIST!!! Don Lemon needs to be FIRED!!     0
# 1               Cnn you should be ashamed of yourselfs     1
# 2    I don't know who this dude is but I like him b...     0
# 3       What is this guy saying? Me not understanding.     1
# 4                     I bet Fareed smells really nice!     0
# ..                                                 ...   ...
# 370                                          Early boi     0
# 371  I thought Trump said he would destroy ISIS in ...     9
# 372                one word LEAVE!!! problem solved!!!     6
# 373                            Trump 2020 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸     8
# 374                    Tariffs on China are justified.     7
#
# [375 rows x 3 columns]

# %%
results = service.commentThreads().list(
    part='snippet',
    videoId='h2RzmSAZ4Hc',
    textFormat='plainText'
    ).execute()
results
# Out:
# {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/Ch7sE3h6MU5KFBBhqwhFGzXuc-c"',
#  'items': [{'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/NTYOXKHg5xAvPbJ7jfJtSf1VMbo"',
#    'id': 'Ugxehoo8XuwLo-HhrX14AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/WHs1LhsohpxUOSzJkKOLfjFJaI4"',
#      'id': 'Ugxehoo8XuwLo-HhrX14AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UC3H3ZmgOxW7bsLwL7PP9z9Q'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC3H3ZmgOxW7bsLwL7PP9z9Q',
#       'authorDisplayName': 'Kobulione',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-2VTLASKKB_s/AAAAAAAAAAI/AAAAAAAAAAA/8FY3KrUrW_k/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-22T11:48:30.000Z',
#       'textDisplay': "USA lost the war in Afghanistan. USA don't have ⚽ s to fight terrorism inside the pakistan.",
#       'textOriginal': "USA lost the war in Afghanistan. USA don't have ⚽ s to fight terrorism inside the pakistan.",
#       'updatedAt': '2019-08-22T11:48:30.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/ikG0NXQxigRDAS8XtGZMUNJ5Cys"',
#    'id': 'Ugzb2W4LY8xOZqoAIbl4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/IMXJWeqh36hpegt5EdcVQRjBnWQ"',
#      'id': 'Ugzb2W4LY8xOZqoAIbl4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCQzxvdElu15Clp4nfwhbHqQ'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQzxvdElu15Clp4nfwhbHqQ',
#       'authorDisplayName': 'India have to Free Kashmir',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-5FEkE2ORKus/AAAAAAAAAAI/AAAAAAAAAAA/ebVYlVK2o6c/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-22T07:42:19.000Z',
#       'textDisplay': 'Afghans are in danger because India keeps chanting terrorism against Pakistan. But infact India is funding terrorists like ISIS and Alqaida in Afghanistan and TTP in Pakistan . For regional peace India have to stop it immediately.',
#       'textOriginal': 'Afghans are in danger because India keeps chanting terrorism against Pakistan. But infact India is funding terrorists like ISIS and Alqaida in Afghanistan and TTP in Pakistan . For regional peace India have to stop it immediately.',
#       'updatedAt': '2019-08-22T07:42:45.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/RHHqu6WOGINskd0KR1ZhZIf5Tr0"',
#    'id': 'UgwOWPUwm07BXyuN3np4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/kkDWM7rwV8BfKaBJwUvAIsZVB4k"',
#      'id': 'UgwOWPUwm07BXyuN3np4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'U
AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/rV0rorsod_YjZqOxJuZLWaGwl0A"',
#      'id': 'UgyzR4JEItBeLSLCR4N4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCcHTPRnk36HEvm9pSwRcOag'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcHTPRnk36HEvm9pSwRcOag',
#       'authorDisplayName': 'rolback',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-UjtXOZ8aU4c/AAAAAAAAAAI/AAAAAAAAAAA/HyU8zDwFoLg/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T14:55:00.000Z',
#       'textDisplay': 'Leave a sign on the door: Next time you harbor a terrorist that attacks the USA, we will not be back for nation building.',
#       'textOriginal': 'Leave a sign on the door: Next time you harbor a terrorist that attacks the USA, we will not be back for nation building.',
#       'updatedAt': '2019-08-20T14:55:00.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/cMa7peYNYzf5cLkpc1FP8LsXqyU"',
#    'id': 'Ugy5awlNO3ZxFjbBTRt4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/NQoJhgoEy3Y9LU7rYyOND1o-fsk"',
#      'id': 'Ugy5awlNO3ZxFjbBTRt4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCdmIAcu8H9yLTkS3xVhT52A'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCdmIAcu8H9yLTkS3xVhT52A',
#       'authorDisplayName': 'twinturbom20',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-k6GPb0d8tXM/AAAAAAAAAAI/AAAAAAAAAAA/bID_ofmw7oQ/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T11:09:31.000Z',
#       'textDisplay': 'If the Taliban keep their promise of establishing a "unity government". Who\'s going to make sure the United States keeps its promise of withdrawal from Afghanistan.',
#       'textOriginal': 'If the Taliban keep their promise of establishing a "unity government". Who\'s going to make sure the United States keeps its promise of withdrawal from Afghanistan.',
#       'updatedAt': '2019-08-20T11:09:31.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/_waoYt0yd1mnd5QScp1R2gVxL7Y"',
#    'id': 'UgwX0q51vNFgHTANAj94AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/1XzoS3v76TknwexAD1hkPsFqHO8"',
#      'id': 'UgwX0q51vNFgHTANAj94AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCfCdkQMvDLbX9IdkIbIZVkw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCfCdkQMvDLbX9IdkIbIZVkw',
#       'authorDisplayName': 'Haat Praat',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-CDSrkwhr4Uk/AAAAAAAAAAI/AAAAAAAAAAA/TNF_j53-_zs/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T09:57:09.000Z',
#       'textDisplay': "The West should just leave. Let the Afghans sort out their own problems. When we leave we should make it clear that if the Islamic nut jobs do a 9/11 on us or anyone else again, we will nuke one of their major population centers. What is the point of spending trillions on nukes if we do not use them? The fear of being nuked kept the Soviets at bay for decades, I'm pretty sure the Jihadis realize whatever they worship is not powerful enough to stop a B-52 armed with a 10 kiloton nuke.",
#       'textOriginal': "The West should just leave. Let the Afghans sort out their own problems. When we leave we should make it clear that if the Islamic nut jobs do a 9/11 on us or anyone else again, we will nuke one of their major population centers. What is the point of spending trillions on nukes if we do not use them? The fear of being nuked kept the Soviets at bay for decades, I'm pretty sure the Jihadis realize whatever they worship is not powerful enough to stop a B-52 armed with a 10 kiloton nuke.",
#       'updatedAt': '2019-08-20T09:57:09.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/8ODFMQsgzw_pILwfDGYvHZNCFXY"',
#    'id': 'UgwmNGhjFUC01uG3-zp4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/FiogqGafuk_QQlAjzqDlaPZkVnk"',
#      'id': 'UgwmNGhjFUC01uG3-zp4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCeXBGQwB1axyZp4stZ8k-VQ'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCeXBGQwB1axyZp4stZ8k-VQ',
#       'authorDisplayName': 'squeento',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-wDbYnNRcRZA/AAAAAAAAAAI/AAAAAAAAAAA/sLGKb9PQZyM/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T08:21:05.000Z',
#       'textDisplay': 'Racist.  Dude is one of those house "en-words"😁.  Just kidding',
#       'textOriginal': 'Racist.  Dude is one of those house "en-words"😁.  Just kidding',
#       'updatedAt': '2019-08-20T08:21:25.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/LmekZx-j0JimuRDYNQtGt2MTcHg"',
#    'id': 'UgzVVI5Nsac7kR4cCg94AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/Tgfooq7y908XM2vuTtJHFCCBOJk"',
#      'id': 'UgzVVI5Nsac7kR4cCg94AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCECdjVzCTdKmSOPWcakxSjw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCECdjVzCTdKmSOPWcakxSjw',
#       'authorDisplayName': 'Jacqueline Wernett',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-L87XOpOaXlY/AAAAAAAAAAI/AAAAAAAAAAA/ceRbSA6kmTM/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T08:14:27.000Z',
#       'textDisplay': 'And yes...3 weeks ago when we tried to delay Russian Proto 4L rocket again...We also confirmed Thursday and Friday that the next rocket would be the March 3...The Chinasat 18 communications satellite is also part  Winnie the Poohs internet...With you Hong Kong and Taiwan...I am laying Easter Eggs...',
#       'textOriginal': 'And yes...3 weeks ago when we tried to delay Russian Proto 4L rocket again...We also confirmed Thursday and Friday that the next rocket would be the March 3...The Chinasat 18 communications satellite is also part  Winnie the Poohs internet...With you Hong Kong and Taiwan...I am laying Easter Eggs...',
#       'updatedAt': '2019-08-20T08:14:27.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/eIgDzWWe4Tkxnfgnedo1sSSfRgE"',
#    'id': 'UgwKcKubnoEyT-dQ4Et4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/0whB0VIBMBol62QvcFOHJBl9b0g"',
#      'id': 'UgwKcKubnoEyT-dQ4Et4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCECdjVzCTdKmSOPWcakxSjw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCECdjVzCTdKmSOPWcakxSjw',
#       'authorDisplayName': 'Jacqueline Wernett',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-L87XOpOaXlY/AAAAAAAAAAI/AAAAAAAAAAA/ceRbSA6kmTM/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T08:10:17.000Z',
#       'textDisplay': "David S.  ...I don't hang out in church reading the Bible...I have never even read the whole Bible...I was not raised religious...I read the Bible when God tells me where to read...about once or twice a week....I have temple in my heart on the go whichever Sabbath a person observes.",
#       'textOriginal': "David S.  ...I don't hang out in church reading the Bible...I have never even read the whole Bible...I was not raised religious...I read the Bible when God tells me where to read...about once or twice a week....I have temple in my heart on the go whichever Sabbath a person observes.",
#       'updatedAt': '2019-08-20T08:10:17.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/FZo4XEiQXqkHUyIQF_4OZlVnf8A"',
#    'id': 'UgyAaj442FtipaWISOR4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/BmKp8wtIBcEkIpgXdVcN2DSL2IY"',
#      'id': 'UgyAaj442FtipaWISOR4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCECdjVzCTdKmSOPWcakxSjw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCECdjVzCTdKmSOPWcakxSjw',
#       'authorDisplayName': 'Jacqueline Wernett',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-L87XOpOaXlY/AAAAAAAAAAI/AAAAAAAAAAA/ceRbSA6kmTM/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T08:01:48.000Z',
#       'textDisplay': 'Afghanistan is because if Russia, Pakistan and Saudi Arabia',
#       'textOriginal': 'Afghanistan is because if Russia, Pakistan and Saudi Arabia',
#       'updatedAt': '2019-08-20T08:01:48.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM
s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 1,
#       'publishedAt': '2019-08-20T06:12:14.000Z',
#       'textDisplay': 'USA is never leaving Afghanistan. Hegemony must be maintained in that region otherwise China or Russia will dominate Eurasia',
#       'textOriginal': 'USA is never leaving Afghanistan. Hegemony must be maintained in that region otherwise China or Russia will dominate Eurasia',
#       'updatedAt': '2019-08-20T06:12:14.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/GMB52uBQPJ9JJqIR-rQVvUpcGaI"',
#    'id': 'UgxHSmuIZ4Zm2-xzS3x4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/kqlHFRPLz9bQAuP55W_1Qk6SPIk"',
#      'id': 'UgxHSmuIZ4Zm2-xzS3x4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCXzBmRcfvOamwu15m1opqog'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCXzBmRcfvOamwu15m1opqog',
#       'authorDisplayName': 'Vinay Kumar',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-1BiVTQFb94E/AAAAAAAAAAI/AAAAAAAAAAA/y51wKIn7-G0/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T03:39:15.000Z',
#       'textDisplay': 'If the Taliban takes over, Afghanistan will plunge back to the 7th century.',
#       'textOriginal': 'If the Taliban takes over, Afghanistan will plunge back to the 7th century.',
#       'updatedAt': '2019-08-20T03:39:15.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/uNctw134reoHRpWb4WLKV8amBJc"',
#    'id': 'Ugz4gYGTKU-VVPlTTGx4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/unqF4TrXuod9QCi5EY3Oc7N-W94"',
#      'id': 'Ugz4gYGTKU-VVPlTTGx4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCwX2vETzlxJvHwsCP_qYw9A'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwX2vETzlxJvHwsCP_qYw9A',
#       'authorDisplayName': 'utubetruthteller utubetruthteller',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-ldxpRVKiY8U/AAAAAAAAAAI/AAAAAAAAAAA/0UE8EkOWxKo/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T02:24:43.000Z',
#       'textDisplay': 'Fareed Zakaria is a sophisticated jihadi that people cannot detect.',
#       'textOriginal': 'Fareed Zakaria is a sophisticated jihadi that people cannot detect.',
#       'updatedAt': '2019-08-20T02:24:43.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/W6C9wWLtq2LC2Qj5EoAYnFz-jzg"',
#    'id': 'UgxispbDvXfJjZaAngB4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/sAJJcUtQaDwJUvV-FpiMjxxFEEU"',
#      'id': 'UgxispbDvXfJjZaAngB4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCALLuW7j9wIIgYAAiirdWVw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCALLuW7j9wIIgYAAiirdWVw',
#       'authorDisplayName': 'Thomas Tamir',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-_h9Teh8rSmc/AAAAAAAAAAI/AAAAAAAAAAA/IIjIdcGHvhU/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T02:22:27.000Z',
#       'textDisplay': "How  would you know? you've never been in uniform, have you?",
#       'textOriginal': "How  would you know? you've never been in uniform, have you?",
#       'updatedAt': '2019-08-20T02:22:27.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}},
#   {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/9Sqwq2GCW2rvFGMBqWp61M7DJt4"',
#    'id': 'UgyBeYrqxb11Dhu5QhB4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/-nyxc6nTuKCjg9UXwoC_ff8lsKs"',
#      'id': 'UgyBeYrqxb11Dhu5QhB4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCe7w3sa3431X766P1BNoLPA'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCe7w3sa3431X766P1BNoLPA',
#       'authorDisplayName': 'Sheikh Raouf',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-edf7-vdX1G4/AAAAAAAAAAI/AAAAAAAAAAA/Ew8p-P0ZTng/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2019-08-20T00:43:28.000Z',
#       'textDisplay': 'Fared is talking about political power sharing in Afghanistan, that is a misnomer. Corrupt political structure is mainly responsible for the chaos in the country. War lords run politics in Afghanistan. US should exit and let the people of Afghanistan decide what they want to do with their country.',
#       'textOriginal': 'Fared is talking about political power sharing in Afghanistan, that is a misnomer. Corrupt political structure is mainly responsible for the chaos in the country. War lords run politics in Afghanistan. US should exit and let the people of Afghanistan decide what they want to do with their country.',
#       'updatedAt': '2019-08-20T00:44:37.000Z',
#       'videoId': 'h2RzmSAZ4Hc',
#       'viewerRating': 'none'}},
#     'totalReplyCount': 0,
#     'videoId': 'h2RzmSAZ4Hc'}}],
#  'kind': 'youtube#commentThreadListResponse',
#  'nextPageToken': 'QURTSl9pM0N0NUcweXJGaWVuU2NsMWh4SjduZnZSSjdqT0tCc0YyOXRtX1FnVVUyeGhmNmFtQW1xLTJhZWFjb0MydUZMc0pWalM0MHppTFJ6WGwyTEJYT3JIallaLVhfWmpVc1JCQ2FlMldCcDdJZHFBWUZJM1B3OUozQlU2b25abWc=',
#  'pageInfo': {'resultsPerPage': 20, 'totalResults': 20}}

# %%
comment_df = pd.DataFrame(columns=['author','comment','likes'])

c = 'comment'
like = 'likes'
autr = 'authorsss'
comment_df.append(pd.Series([c,like,autr],index=comment_df.columns), ignore_index = True)
# Out:
#     author comment      likes
# 0  comment   likes  authorsss

# %%
def search_channel(service, search_term):
    request = service.search().list(
        q=search_term,
        part='id,snippet',
        type='channel',
        maxResults='20'
    ).execute()
    
    channel_df = pd.DataFrame(columns=['channel_id','channel'])
    for results in request:
        chan = request['items'][0]['channelTitle']
        c_id = request['items'][0]['channelId']
        channel_df = channel_df.append(pd.Series([chan, c_id],index=channel_df.columns), ignore_index = True)
    
    return channel_df
        


def find_channel_id(service, search_term):
    request = service.channels().list(
    forUsername=search_term,
    part='id,snippet'
    ).execute()
    channel_id = request['items'][0]['id']
    return channel_id


comment_df = pd.DataFrame(columns=['author','comment','likes'])
    results = service.commentThreads().list(**kwargs).execute()
 
    while results:
        for item in results['items']:
            author = item['snippet']['topLevelComment']['snippet']['authorChannelId']
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            likes = item['snippet']['topLevelComment']['snippet']['likeCount']
            comment_df = comment_df.append(pd.Series([author,comment,likes],index=comment_df.columns), ignore_index = True)

request = service.search().list(
    q='cnn',
    part='id,snippet',
    type='channel',
    maxResults='20'
    )
request.execute()
# Out:
# {'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/2S6eo54pG9JE-sVJqQDFyabAO5E"',
#  'items': [{'etag': '"0UM_wBUsFuT6ekiIlwaHvyqc80M/f10hjuC3bLJD8gUed_U6_N0H5L0"',
#    'id': {'channelId': 'UCupvZG-5ko_eiXAupbDfxWw', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCupvZG-5ko_eiXAupbDfxWw',
#     'channelTitle': 'CNN',
#     'description': 'CNN operates as a division of Turner Broadcasting System, which is a subsidiary of Warner Media. CNN identifies itself as -- and is widely known to be - the ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '